# %%
import os
import numpy as np
import json
import pickle as pkl

# %% [markdown]
# # Get file path

# %%
def document_path_list(mvt_path):
    method_dir = ["blazepose","openpose", "kinect"]
    group_dir = os.listdir(mvt_path)
#     dic_mvt ={}
    dic_group = {}
    for group_name in group_dir:
        group_path = os.path.join(mvt_path,group_name)
#         print(group_path)
        dic_method = {}
        for method_name in method_dir:
            method_path = os.path.join(group_path,method_name)
            json_dir = os.listdir(method_path)
            
            file_read_list = []
            for json_name in json_dir:
                file_read_path = os.path.join(method_path,json_name)
                file_read_list.append(file_read_path)
#                 print(file_read_path)
            dic_method[method_name] = sorted(file_read_list)
        dic_group[group_name] = dic_method
    return dic_group

# %%
dic = document_path_list("../data")

# %%
print(dic.keys())
# for i in range(len(dic['group1A']['blazepose'])):
#     print(dic['group1A']['blazepose'][i])
#     print(dic['group1A']['openpose'][i])
#     print(dic['group1A']['kinect'][i])
#     print()

for group in dic.keys():
    for i in range(len(dic[group]["openpose"])):
        open_file = open(dic[group]['openpose'][i],'r+')
        blaze_file = open(dic[group]["blazepose"][i],'r+')
        open_dic = json.loads(open_file.read())
        blaze_dic = json.loads(blaze_file.read())
        
        len_open = len(open_dic["positions"])
        len_blaze = len(blaze_dic["positions"])
        
        if len_open - len_blaze > len_open/2:
            print(dic[group]['blazepose'][i], len_blaze)
            print(dic[group]['openpose'][i], len_open)
            print()
# Out:
# dict_keys(['group1A', 'group1B', 'group2A', 'group2B', 'group3'])
# ../data\group1A\blazepose\G1A-Faces-CTK-R6-Roscoff-006.json 154
# ../data\group1A\openpose\G1A-Anon-CTK-R6-Roscoff-006.json 391
#
# ../data\group1A\blazepose\G1A-Faces-CTK-R6-Roscoff-082.json 3
# ../data\group1A\openpose\G1A-Anon-CTK-R6-Roscoff-082.json 399
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R4-Roscoff-009.json 2
# ../data\group1A\openpose\G1A-Anon-ELK-R4-Roscoff-009.json 476
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R4-Roscoff-031.json 157
# ../data\group1A\openpose\G1A-Anon-ELK-R4-Roscoff-031.json 483
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R4-Roscoff-036.json 1
# ../data\group1A\openpose\G1A-Anon-ELK-R4-Roscoff-036.json 477
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R4-Roscoff-045.json 187
# ../data\group1A\openpose\G1A-Anon-ELK-R4-Roscoff-045.json 503
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-010.json 7
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-010.json 524
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-023.json 51
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-023.json 517
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-043.json 249
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-043.json 563
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-044.json 209
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-044.json 542
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-078.json 239
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-078.json 546
#
# ../data\group1A\blazepose\G1A-Faces-ELK-R6-Roscoff-090.json 254
# ../data\group1A\openpose\G1A-Anon-ELK-R6-Roscoff-090.json 533
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R4-Roscoff-014.json 91
# ../data\group1A\openpose\G1A-Anon-RTK-R4-Roscoff-014.json 450
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R4-Roscoff-017.json 0
# ../data\group1A\openpose\G1A-Anon-RTK-R4-Roscoff-017.json 468
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R4-Roscoff-081.json 118
# ../data\group1A\openpose\G1A-Anon-RTK-R4-Roscoff-081.json 441
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R4-Roscoff-090.json 162
# ../data\group1A\openpose\G1A-Anon-RTK-R4-Roscoff-090.json 399
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R4-Roscoff-091.json 111
# ../data\group1A\openpose\G1A-Anon-RTK-R4-Roscoff-091.json 461
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R6-Roscoff-002.json 129
# ../data\group1A\openpose\G1A-Anon-RTK-R6-Roscoff-002.json 434
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R6-Roscoff-013.json 134
# ../data\group1A\openpose\G1A-Anon-RTK-R6-Roscoff-013.json 413
#
# ../data\group1A\blazepose\G1A-Faces-RTK-R6-Roscoff-037.json 0
# ../data\group1A\openpose\G1A-Anon-RTK-R6-Roscoff-037.json 409
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-208.json 0
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-208.json 408
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-209.json 49
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-209.json 400
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-210.json 3
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-210.json 420
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-211.json 75
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-211.json 412
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-212.json 9
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-212.json 443
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-213.json 3
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-213.json 411
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-214.json 3
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-214.json 386
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-218.json 8
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-218.json 381
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-219.json 137
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-219.json 415
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-220.json 15
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-220.json 394
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-221.json 194
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-221.json 408
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-222.json 67
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-222.json 434
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-223.json 8
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-223.json 441
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-224.json 1
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-224.json 416
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-227.json 68
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-227.json 436
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-262.json 19
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-262.json 435
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-264.json 68
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-264.json 376
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-265.json 19
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-265.json 398
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-266.json 8
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-266.json 367
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-267.json 41
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-267.json 377
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-268.json 0
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-268.json 374
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-269.json 11
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-269.json 383
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-270.json 15
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-270.json 408
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-271.json 54
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-271.json 367
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-284.json 116
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-284.json 314
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-285.json 14
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-285.json 359
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-286.json 22
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-286.json 351
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-287.json 2
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-287.json 355
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-288.json 11
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-288.json 369
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-290.json 138
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-290.json 361
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-291.json 32
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-291.json 353
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-292.json 3
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-292.json 462
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-294.json 3
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-294.json 365
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-303.json 169
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-303.json 380
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-308.json 175
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-308.json 354
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-338.json 20
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-338.json 461
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-524.json 163
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-524.json 360
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-526.json 146
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-526.json 356
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-527.json 142
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-527.json 359
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-575.json 2
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-575.json 364
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-577.json 0
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-577.json 386
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-578.json 0
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-578.json 360
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-583.json 9
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-583.json 368
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-586.json 1
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-586.json 362
#
# ../data\group1B\blazepose\G1B-Faces-CTK-Roscoff-587.json 6
# ../data\group1B\openpose\G1B-Anon-CTK-Roscoff-587.json 447
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-158.json 168
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-158.json 507
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-162.json 61
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-162.json 453
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-178.json 74
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-178.json 577
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-179.json 176
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-179.json 559
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-182.json 75
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-182.json 474
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-184.json 45
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-184.json 456
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-185.json 52
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-185.json 487
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-186.json 13
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-186.json 482
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-209.json 192
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-209.json 501
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-221.json 63
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-221.json 327
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-225.json 148
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-225.json 498
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-226.json 263
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-226.json 543
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-227.json 284
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-227.json 585
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-235.json 291
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-235.json 593
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-240.json 227
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-240.json 662
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-251.json 230
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-251.json 556
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-255.json 162
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-255.json 452
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-256.json 0
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-256.json 471
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-259.json 129
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-259.json 576
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-262.json 30
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-262.json 551
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-263.json 19
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-263.json 532
#
# ../data\group1B\blazepose\G1B-Faces-ELK-Roscoff-265.json 1
# ../data\group1B\openpose\G1B-Anon-ELK-Roscoff-265.json 535
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-199.json 4
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-199.json 397
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-200.json 44
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-200.json 419
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-201.json 76
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-201.json 392
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-203.json 172
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-203.json 420
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-204.json 54
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-204.json 408
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-205.json 144
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-205.json 405
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-249.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-249.json 426
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-250.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-250.json 464
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-251.json 6
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-251.json 435
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-256.json 9
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-256.json 400
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-259.json 194
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-259.json 409
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-268.json 70
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-268.json 428
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-269.json 36
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-269.json 405
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-270.json 80
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-270.json 412
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-278.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-278.json 402
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-279.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-279.json 488
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-280.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-280.json 390
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-281.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-281.json 453
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-282.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-282.json 399
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-283.json 124
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-283.json 417
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-284.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-284.json 446
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-285.json 0
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-285.json 467
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-292.json 155
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-292.json 388
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-500.json 102
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-500.json 434
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-501.json 91
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-501.json 480
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-560.json 218
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-560.json 443
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-561.json 192
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-561.json 457
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-563.json 145
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-563.json 382
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-564.json 156
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-564.json 412
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-567.json 94
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-567.json 403
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-569.json 181
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-569.json 408
#
# ../data\group1B\blazepose\G1B-Faces-RTK-Roscoff-570.json 39
# ../data\group1B\openpose\G1B-Anon-RTK-Roscoff-570.json 410
#
# ../data\group2A\blazepose\G2A-Faces-CTK-S4-Roscoff-046.json 203
# ../data\group2A\openpose\G2A-Anon-CTK-S4-Roscoff-046.json 426
#
# ../data\group2A\blazepose\G2A-Faces-CTK-S4-Roscoff-074.json 28
# ../data\group2A\openpose\G2A-Anon-CTK-S4-Roscoff-074.json 401
#
# ../data\group2B\blazepose\G2B-Faces-CTK-Roscoff-136.json 1
# ../data\group2B\openpose\G2B-Anon-CTK-Roscoff-136.json 368
#
# ../data\group2B\blazepose\G2B-Faces-CTK-Roscoff-138.json 36
# ../data\group2B\openpose\G2B-Anon-CTK-Roscoff-138.json 368
#
# ../data\group2B\blazepose\G2B-Faces-CTK-Roscoff-139.json 31
# ../data\group2B\openpose\G2B-Anon-CTK-Roscoff-139.json 365
#
# ../data\group2B\blazepose\G2B-Faces-CTK-Roscoff-140.json 49
# ../data\group2B\openpose\G2B-Anon-CTK-Roscoff-140.json 363
#
# ../data\group2B\blazepose\G2B-Faces-CTK-Roscoff-141.json 77
# ../data\group2B\openpose\G2B-Anon-CTK-Roscoff-141.json 370
#
# ../data\group2B\blazepose\G2B-Faces-RTK-Roscoff-143.json 0
# ../data\group2B\openpose\G2B-Anon-RTK-Roscoff-143.json 401
#
# ../data\group2B\blazepose\G2B-Faces-RTK-Roscoff-144.json 2
# ../data\group2B\openpose\G2B-Anon-RTK-Roscoff-144.json 416
#
# ../data\group2B\blazepose\G2B-Faces-RTK-Roscoff-654.json 150
# ../data\group2B\openpose\G2B-Anon-RTK-Roscoff-654.json 451
#
# ../data\group3\blazepose\G3-Faces-CTK-P2T3-Unknown-E3B3-0.json 91
# ../data\group3\openpose\G3-Anon-CTK-P2T3-Unknown-E3B3-0.json 257

# %% [markdown]
# # Convert in openpose

# %%
def kinToOpen_formule(kin_point,kin_ref,open_ref,dis_ref_kin,dis_ref_open):
    kin_point = np.array(kin_point)
    dis = np.linalg.norm(kin_point-kin_ref)
    dis_open = dis/dis_ref_kin*dis_ref_open
    return (kin_point-kin_ref)*dis_open+open_ref

# %%
## Convertir le coords de Kinect en coords de Openpose
def convertir_kinect_en_openpose(kin_temp,open_temp):
#     print(open_temp.keys())
    if 'lHip' not in open_temp.keys() or 'rHip' not in open_temp.keys():
        open_temp['mHip'] = [np.nan, np.nan]
    else:
        open_temp['mHip'] = [(open_temp['lHip'][0]+open_temp['rHip'][0])/2,(open_temp['lHip'][1]+open_temp['rHip'][1])/2]
    if 'mShoulder' not in open_temp.keys():
        open_temp['mShoulder'] = [np.nan, np.nan]
    dis_ref_open = np.linalg.norm([open_temp["mHip"][0]-open_temp["mShoulder"][0],open_temp["mHip"][1]-open_temp["mShoulder"][1]])
    dis_ref_kin = np.linalg.norm([kin_temp[0*7]-kin_temp[20*7],kin_temp[0*7+1]-kin_temp[20*7+1]])
    point_ref_open = np.array(open_temp["mShoulder"])
    point_ref_kin = np.array([kin_temp[20*7], kin_temp[20*7+1]]) #mShoulder
    kintoOpen = {}

    ## Body part
    kintoOpen["Head"]= np.hstack([kinToOpen_formule([kin_temp[3*7],kin_temp[3*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[3*7+2]-kin_temp[20*7+2]])
    kintoOpen["mShoulder"] = np.hstack([kinToOpen_formule([kin_temp[20*7],kin_temp[20*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[20*7+2]-kin_temp[20*7+2]])
    ## Right arm
    kintoOpen["rShoulder"] = np.hstack([kinToOpen_formule([kin_temp[8*7],kin_temp[8*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[8*7+2]-kin_temp[20*7+2]])
    kintoOpen["rElbow"] = np.hstack([kinToOpen_formule([kin_temp[9*7],kin_temp[9*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[9*7+2]-kin_temp[20*7+2]])
    kintoOpen["rWrist"] = np.hstack([kinToOpen_formule([kin_temp[10*7],kin_temp[10*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[10*7+2]-kin_temp[20*7+2]])
    ## Left arm
    kintoOpen["lShoulder"] = np.hstack([kinToOpen_formule([kin_temp[4*7],kin_temp[4*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[4*7+2]-kin_temp[20*7+2]])
    kintoOpen["lElbow"] = np.hstack([kinToOpen_formule([kin_temp[5*7],kin_temp[5*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[5*7+2]-kin_temp[20*7+2]])
    kintoOpen["lWrist"] = np.hstack([kinToOpen_formule([kin_temp[6*7],kin_temp[6*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[6*7+2]-kin_temp[20*7+2]])
    ## Right leg
    kintoOpen["rHip"] = np.hstack([kinToOpen_formule([kin_temp[16*7],kin_temp[16*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[16*7+2]-kin_temp[20*7+2]])
    kintoOpen["rKnee"] = np.hstack([kinToOpen_formule([kin_temp[17*7],kin_temp[17*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[17*7+2]-kin_temp[20*7+2]])
    kintoOpen["rAnkle"] = np.hstack([kinToOpen_formule([kin_temp[18*7],kin_temp[18*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[18*7+2]-kin_temp[20*7+2]])
    ## Left leg
    kintoOpen["lHip"] = np.hstack([kinToOpen_formule([kin_temp[12*7],kin_temp[12*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[12*7+2]-kin_temp[20*7+2]])      
    kintoOpen["lKnee"] = np.hstack([kinToOpen_formule([kin_temp[13*7],kin_temp[13*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[13*7+2]-kin_temp[20*7+2]])
    kintoOpen["lAnkle"] = np.hstack([kinToOpen_formule([kin_temp[14*7],kin_temp[14*7+1]],point_ref_kin,point_ref_open,dis_ref_kin,dis_ref_open),kin_temp[14*7+2]-kin_temp[20*7+2]])
    return kintoOpen

def convertir_blazepose_en_openpose(bla_temp):
    sklt_bla = list(bla_temp.keys())
    deep_ref = (bla_temp[sklt_bla[11]][2]+bla_temp[sklt_bla[12]][2])/2
    blaztoOpen = {}
    blaztoOpen["Head"] = np.array(bla_temp[sklt_bla[0]])-np.array([0,0,deep_ref])
    blaztoOpen["mShoulder"] = np.array([(bla_temp[sklt_bla[11]][0]+bla_temp[sklt_bla[12]][0])/2,
                                        (bla_temp[sklt_bla[11]][1]+bla_temp[sklt_bla[12]][1])/2,
                                        (bla_temp[sklt_bla[11]][2]+bla_temp[sklt_bla[12]][2])/2])-np.array([0,0,deep_ref])
    ## Right arm
    blaztoOpen["rShoulder"] = np.array(bla_temp[sklt_bla[12]])-np.array([0,0,deep_ref])
    blaztoOpen["rElbow"] = np.array(bla_temp[sklt_bla[14]])-np.array([0,0,deep_ref])
    blaztoOpen["rWrist"] = np.array(bla_temp[sklt_bla[16]])-np.array([0,0,deep_ref])
    ## Left arm
    blaztoOpen["lShoulder"] = np.array(bla_temp[sklt_bla[11]])-np.array([0,0,deep_ref])
    blaztoOpen["lElbow"] = np.array(bla_temp[sklt_bla[13]])-np.array([0,0,deep_ref])
    blaztoOpen["lWrist"] = np.array(bla_temp[sklt_bla[15]])-np.array([0,0,deep_ref])
    ## Right leg
    blaztoOpen["rHip"] = np.array(bla_temp[sklt_bla[24]])-np.array([0,0,deep_ref])
    blaztoOpen["rKnee"] = np.array(bla_temp[sklt_bla[26]])-np.array([0,0,deep_ref])
    blaztoOpen["rAnkle"] = np.array(bla_temp[sklt_bla[28]])-np.array([0,0,deep_ref])
    ## Left leg
    blaztoOpen["lHip"] = np.array(bla_temp[sklt_bla[23]])-np.array([0,0,deep_ref])
    blaztoOpen["lKnee"] = np.array(bla_temp[sklt_bla[25]])-np.array([0,0,deep_ref])
    blaztoOpen["lAnkle"] = np.array(bla_temp[sklt_bla[27]])-np.array([0,0,deep_ref])

    return blaztoOpen

# %% [markdown]
# # Compare Error

# %%
def compare_blazepose_kinect_openpose_onevideo(blaze_file, kinect_file, open_file):
    print(blaze_file.name)
    print(kinect_file.name)
    print(open_file.name)
    print()
    open_dic = json.loads(open_file.read())
    open_all_frame = open_dic['positions']
    blaze_dic = json.loads(blaze_file.read())
    blaze_all_frame = blaze_dic['positions']
    kinect_all_frame = kinect_file.read().split("\n")
    frame_min = min(len(open_all_frame.keys()),len(blaze_all_frame.keys()),len(kinect_all_frame))
    list_sklt = ["Head","mShoulder",
                "rShoulder","rElbow","rWrist","lShoulder","lElbow","lWrist",
                "rHip","rKnee","rAnkle","lHip","lKnee","lAnkle"]
    Error_blazeOpen_frame = {}
    Error_KintOpen_frame = {}
    Error_blazeKint_frame_sansP = {}
    Error_blazeKint_frame_avecP = {}
    for sklt in list_sklt:
        Error_blazeOpen_frame[sklt] = np.zeros(frame_min)
        Error_KintOpen_frame[sklt] = np.zeros(frame_min)
        Error_blazeKint_frame_sansP[sklt] = np.zeros(frame_min)
        Error_blazeKint_frame_avecP[sklt] = np.zeros(frame_min)
#         print("k: ", len_kin,", b: ", len_bla)
    for frame in range(frame_min):
        blaze_temp = blaze_all_frame[str(frame+1)+".0"]
        kin_temp = np.array(kinect_all_frame[frame].split(" ")[:-1]).astype(float)
        open_sklt = open_all_frame[str(frame+1)+".0"]
#         print("frame: ", frame)
#         print(blaze_temp)
        blaze_sklt = convertir_blazepose_en_openpose(blaze_temp)
#         if len(blaze_sklt) != len(open_sklt):
#             continue
        if len(kin_temp) == 0:
            continue
        kin_sklt = convertir_kinect_en_openpose(kin_temp,open_sklt)
#         print(blaze_sklt)
#         print(kin_sklt)
#         print("frame yesyes : ", frame)
        for ske in list_sklt:
            # print(np.linalg.norm(blaze_sklt[ske]-np.array(open_sklt[ske])))
            # print("blaze: ",blaze_sklt)
#             print("Open: ", open_sklt.keys(),"\n")
            if ske not in open_sklt.keys():
                Error_blazeOpen_frame[ske][frame] = np.nan
                Error_KintOpen_frame[ske][frame] = np.nan
                Error_blazeKint_frame_sansP[ske][frame] = np.nan
                Error_blazeKint_frame_avecP[ske][frame] = np.nan
            else:
                Error_blazeOpen_frame[ske][frame] = np.linalg.norm(blaze_sklt[ske][:-1] - np.array(open_sklt[ske]))
                Error_KintOpen_frame[ske][frame] = np.linalg.norm(kin_sklt[ske][:-1] - np.array(open_sklt[ske]))
                Error_blazeKint_frame_sansP[ske][frame] = np.linalg.norm(blaze_sklt[ske][:-1]-kin_sklt[ske][:-1])
                Error_blazeKint_frame_avecP[ske][frame] = np.linalg.norm(blaze_sklt[ske]-kin_sklt[ske])
    return Error_blazeOpen_frame, Error_KintOpen_frame, Error_blazeKint_frame_sansP, Error_blazeKint_frame_avecP

# %%
# open_file = open(dic['group1A']['openpose'][1],'r+')
# blaze_file = open(dic['group1A']['blazepose'][1],'r+')
# kinect_file = open(dic['group1A']['kinect'][1],'r+')
# Error_blaOp, Error_kintOp, Error_blaKin_sansP,Error_blaKin_avecP = compare_blazepose_kinect_openpose_onevideo(blaze_file,kinect_file,open_file)
# kinect_file.close()
# blaze_file.close()
# open_file.close()
# print(Error_blaKin_sansP)
# print(Error_blaKin_avecP)
# print(Error_blaOp)
# print(Error_kintOp)

# %%
# for i in range(len(dic['group1A']['blazepose'])):
#     open_file = open(dic['group1A']['openpose'][i],'r+')
#     blaze_file = open(dic['group1A']['blazepose'][i],'r+')
#     kinect_file = open(dic['group1A']['kinect'][i],'r+')
#     Error_blaOp, Error_kintOp, Error_blaKin_sansP,Error_blaKin_avecP = compare_blazepose_kinect_openpose_onevideo(blaze_file,kinect_file,open_file)
#     kinect_file.close()
#     blaze_file.close()
#     open_file.close()
# #     print(Error_blaKin_sansP)
# #     print(Error_blaKin_avecP)
# #     print(Error_blaOp)
# #     print(Error_kintOp)

# %%
a = np.array([1,1,1,np.nan])
b = np.array([1,1,1,1])
print(b+a)
print([np.nan,np.nan])
# Out:
# [ 2.  2.  2. nan]
# [nan, nan]

# %% [markdown]
# # Error for all video

# %%
def get_error_dic(dic):
    Error_dic = {}
    list_sklt = ["Head","mShoulder",
                    "rShoulder","rElbow","rWrist","lShoulder","lElbow","lWrist",
                    "rHip","rKnee","rAnkle","lHip","lKnee","lAnkle"]
    list_error = ['Error_blazeOpen_par_mvt', 'Error_KintOpen_par_mvt', 
                    'Error_blazeKint_sansP_par_mvt','Error_blazeKint_avecP_par_mvt']

    for group in dic.keys():
        Error_group = {}
        blazepose_list = dic[group]['blazepose']
        openpose_list = dic[group]['openpose']
        kinect_list = dic[group]['kinect']
        lenlist = len(blazepose_list)
    #     print(len(blazepose_list))

    #     print(len(openpose_list))
    #     print(len(kinect_list))
        for Error_name in list_error:
            Error_group[Error_name] = {}
            for skl in list_sklt:
                Error_group[Error_name][skl] = {}
    #     print(Error_group)
        
        mvt_total = {}
        for i in range(lenlist):
            print("%s, (%d/%d)"%(group, i+1, lenlist))
            path_name = blazepose_list[i]
            mvt = path_name.split('/')[-1].split('-')[2]
            print(mvt)
            if mvt not in mvt_total.keys():
                for Error_name in list_error:
                    for skl_name in list_sklt:
                        Error_group[Error_name][skl_name][mvt] = np.zeros(lenlist)
                mvt_total[mvt] = 0
            else:
                mvt_total[mvt] += 1
            
            open_file = open(openpose_list[i],'r+')
            blaze_file = open(blazepose_list[i],'r+')
            kin_file = open(kinect_list[i],"r+")
            Error_blazeOpen_one, Error_kinOpen_one, Error_blazeKint_sansP_one, Error_blazeKint_avecP_one = compare_blazepose_kinect_openpose_onevideo(blaze_file,kin_file,open_file)
            open_file.close()
            blaze_file.close()
            kin_file.close()
            for skl in list_sklt:
                Error_group["Error_blazeOpen_par_mvt"][skl][mvt][mvt_total[mvt]] = np.nanmean(Error_blazeOpen_one[skl])
                Error_group["Error_KintOpen_par_mvt"][skl][mvt][mvt_total[mvt]] = np.nanmean(Error_kinOpen_one[skl])
                Error_group["Error_blazeKint_sansP_par_mvt"][skl][mvt][mvt_total[mvt]] = np.nanmean(Error_blazeKint_sansP_one[skl])
                Error_group["Error_blazeKint_avecP_par_mvt"][skl][mvt][mvt_total[mvt]] = np.nanmean(Error_blazeKint_avecP_one[skl])
        Error_dic[group] = Error_group
    return Error_dic

# %%
dic = document_path_list("../data")

# %%
dic = document_path_list("../data")
Error_dic = get_error_dic(dic)

import pickle as pkl
re = "../results/pkls"
if not os.path.exists(re):
    os.mkdir(re)
Error_path = os.path.join(re,"Error_all_group.pkl")
with open(Error_path,'wb') as f:
    pkl.dump(Error_dic, f)
# print(Error_dic)

# %%
# with open(Error_path, 'rb') as g:
#     Error = pkl.load(g)

# %% [markdown]
# # Error for mvt mean

# %%
def get_error_mean(Error_all):
#     group_mean = ['group1A', 'group2A']
    Error_mean = {}
    Error_std = {}
    for group_name in Error_all.keys():
        Error_mean[group_name] = {}
        Error_std[group_name] = {}
        for error_type in Error_all[group_name].keys():
            Error_mean[group_name][error_type] = {}
            Error_std[group_name][error_type] = {}
            for sklt in Error_all[group_name][error_type].keys():
                Error_mean[group_name][error_type][sklt] = {}
                Error_std[group_name][error_type][sklt] = {}
                for mvt in Error_all[group_name][error_type][sklt].keys():
                    temp_arr = Error_all[group_name][error_type][sklt][mvt]
    #                 print(temp_arr)
                    Error_mean[group_name][error_type][sklt][mvt] = np.nanmean(np.where(temp_arr!=0,temp_arr,np.nan))
                    Error_std[group_name][error_type][sklt][mvt] = np.nanstd(np.where(temp_arr!=0,temp_arr,np.nan))
    return Error_mean, Error_std

# %%
with open("../results/pkls/Error_all_group.pkl", 'rb') as f:
    Error_dic = pkl.load(f)
f.close()

re = "../results/pkls"
Error_mean_path = os.path.join(re,"Error_mean_group.pkl")
Error_std_path = os.path.join(re,"Error_std_group.pkl")

Error_mean_dic, Error_std_dic = get_error_mean(Error_dic)

with open(Error_mean_path,'wb') as g:
    pkl.dump(Error_mean_dic, g)
g.close()
with open(Error_std_path,'wb') as h:
    pkl.dump(Error_std_dic, h)
h.close()
# Out:
# /home/guoyu/anaconda3/envs/keraal/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: Mean of empty slice
#   app.launch_new_instance()
# /home/guoyu/anaconda3/envs/keraal/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1671: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
for group in Error_dic.keys():
    for eType in Error_dic[group].keys():
        for articulation in Error_dic[group][eType].keys():
            print(group, eType, articulation, Error_dic[group][eType][articulation])
# print(Error_dic)
